# %% [markdown]
# <a href="https://colab.research.google.com/github/hsrpedro006/Collab-/blob/codigos/aula_2_fiap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Exemplos aula 3

# %% [markdown]
# #Bibliotecas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #Carregar os dados

# %%
dados = pd.read_csv('dados_1997_2011_paises_csv.csv',
                encoding='latin', sep = ';' , decimal = ',')

# %%
# verificar o tipo de dado
dados.dtypes
# Out:
# pais                       object
# ano                         int64
# idh                       float64
# corrupcao_indice            int64
# competitividade_indice    float64
# globalizacao_indice       float64
# pib                       float64
# populacao                 float64
# dtype: object

# %%
# ver as primeiras linhas
dados.head()
# Out:
#             pais   ano     idh  corrupcao_indice  competitividade_indice  \
# 0  África do Sul  1997  0.6328                56                   44.54
# 1  África do Sul  1998  0.6272                57                   31.11
# 2  África do Sul  1999  0.6216                50                   43.90
# 3  África do Sul  2000  0.6160                52                   51.52
# 4  África do Sul  2001  0.6126                50                   45.12
#
#    globalizacao_indice          pib  populacao
# 0             52.60298  148814151.0  43353.632
# 1             54.51911  134295557.0  43961.924
# 2             61.04379  133183581.0  44526.272
# 3             62.47182  132877648.0  45064.098
# 4             62.04144  118478979.0  45576.215

# %%
# ver as últimas linhas
dados.tail()
# Out:
#             pais   ano    idh  corrupcao_indice  competitividade_indice  \
# 280  Reino Unido  2007  0.856                86                   75.45
# 281  Reino Unido  2008  0.860                86                   71.90
# 282  Reino Unido  2009  0.860                84                   76.07
# 283  Reino Unido  2010  0.862                77                   76.81
# 284  Reino Unido  2011  0.863                77                   80.28
#
#      globalizacao_indice          pib    populacao
# 280             82.12010  1448770.274  61337.36992
# 281             81.67998  1447824.983  61731.27576
# 282             79.31000  1377246.729  62086.03336
# 283             80.18000  1395893.408  62438.13815
# 284             81.68000  1500045.000  62262.00000

# %% [markdown]
# #Seleção de colunas

# %%
# ver todas as colunas
dados.columns
# Out:
# Index(['pais', 'ano', 'idh', 'corrupcao_indice', 'competitividade_indice',
#        'globalizacao_indice', 'pib', 'populacao'],
#       dtype='object')

# %%
# contar o  número de colunas
len(dados.columns)
# Out:
# 8

# %%
# selecionar uma coluna
dados['pais']
# Out:
# 0      África do Sul
# 1      África do Sul
# 2      África do Sul
# 3      África do Sul
# 4      África do Sul
#            ...
# 280      Reino Unido
# 281      Reino Unido
# 282      Reino Unido
# 283      Reino Unido
# 284      Reino Unido
# Name: pais, Length: 285, dtype: object

# %%
# selecionar mais de uma coluna
dados[['pais', 'idh']]
# Out:
#               pais     idh
# 0    África do Sul  0.6328
# 1    África do Sul  0.6272
# 2    África do Sul  0.6216
# 3    África do Sul  0.6160
# 4    África do Sul  0.6126
# ..             ...     ...
# 280    Reino Unido  0.8560
# 281    Reino Unido  0.8600
# 282    Reino Unido  0.8600
# 283    Reino Unido  0.8620
# 284    Reino Unido  0.8630
#
# [285 rows x 2 columns]

# %%
# outro padrão para selecionar colunas (padrão melhor a ser usado)
cols = ['pais', 'ano', 'idh']
dados[cols]
# Out:
#               pais   ano     idh
# 0    África do Sul  1997  0.6328
# 1    África do Sul  1998  0.6272
# 2    África do Sul  1999  0.6216
# 3    África do Sul  2000  0.6160
# 4    África do Sul  2001  0.6126
# ..             ...   ...     ...
# 280    Reino Unido  2007  0.8560
# 281    Reino Unido  2008  0.8600
# 282    Reino Unido  2009  0.8600
# 283    Reino Unido  2010  0.8620
# 284    Reino Unido  2011  0.8630
#
# [285 rows x 3 columns]

# %% [markdown]
# # Filtros

# %%
# numero de linhas e colunas
dados.shape
# Out:
# (285, 8)

# %%
# numero de linhas
dados.shape[0]
# Out:
# 285

# %%
# filtrar numeros
dados[dados['ano'] == 2010]
# Out:
#                pais   ano    idh  corrupcao_indice  competitividade_indice  \
# 13    África do Sul  2010  0.615                49                   54.09
# 28         Alemanha  2010  0.903                79                   82.73
# 43        Austrália  2010  0.927                87                   92.17
# 58          Bélgica  2010  0.885                73                   73.59
# 73           Brasil  2010  0.715                35                   56.53
# 88           Canadá  2010  0.907                87                   90.46
# 103           China  2010  0.682                36                   80.18
# 118       Cingapura  2010  0.864                92                  100.00
# 133          Coréia  2010  0.894                56                   76.25
# 148         Espanha  2010  0.876                65                   58.75
# 163  Estados Unidos  2010  0.908                73                   99.09
# ...

# %%
# filtrar numeros
dados[dados['ano'] >= 2010].head(1)
# Out:
#              pais   ano    idh  corrupcao_indice  competitividade_indice  \
# 13  África do Sul  2010  0.615                49                   54.09
#
#     globalizacao_indice          pib  populacao
# 13                 65.6  363703903.0  49109.107

# %%
# filtrar texto
dados[dados['pais'] == 'Brasil']
# Out:
#       pais   ano     idh  corrupcao_indice  competitividade_indice  \
# 60  Brasil  1997  0.6464                27                   54.14
# 61  Brasil  1998  0.6526                30                   39.98
# 62  Brasil  1999  0.6588                36                   52.84
# 63  Brasil  2000  0.6650                40                   52.23
# 64  Brasil  2001  0.6704                41                   43.79
# 65  Brasil  2002  0.6758                39                   43.91
# 66  Brasil  2003  0.6812                40                   44.49
# 67  Brasil  2004  0.6866                40                   48.13
# 68  Brasil  2005  0.6920                39                   49.86
# 69  Brasil  2006  0.6950                39                   46.42
# 70  Brasil  2007  0.7000                37                   44.71
# 71  Brasil  2008  0.7050                33                   48.58
# 72  Brasil  2009  0.7080                35                   56.87
# ...

# %%
# filtrar texto contendo padraão
dados[dados['pais'].str.contains('sil')]
# Out:
#       pais   ano     idh  corrupcao_indice  competitividade_indice  \
# 60  Brasil  1997  0.6464                27                   54.14
# 61  Brasil  1998  0.6526                30                   39.98
# 62  Brasil  1999  0.6588                36                   52.84
# 63  Brasil  2000  0.6650                40                   52.23
# 64  Brasil  2001  0.6704                41                   43.79
# 65  Brasil  2002  0.6758                39                   43.91
# 66  Brasil  2003  0.6812                40                   44.49
# 67  Brasil  2004  0.6866                40                   48.13
# 68  Brasil  2005  0.6920                39                   49.86
# 69  Brasil  2006  0.6950                39                   46.42
# 70  Brasil  2007  0.7000                37                   44.71
# 71  Brasil  2008  0.7050                33                   48.58
# 72  Brasil  2009  0.7080                35                   56.87
# ...

# %%
# mais de 1 filtro
dados[(dados['pais'] == 'Brasil') &
 (dados['ano'] == 2010)]
# Out:
#       pais   ano    idh  corrupcao_indice  competitividade_indice  \
# 73  Brasil  2010  0.715                35                   56.53
#
#     globalizacao_indice           pib    populacao
# 73                60.38  2.087900e+09  201103.2515

# %%
# filtros valores numa lista
dados[dados['pais'].isin(['Brasil', 'Canadá'])]
# Out:
#       pais   ano     idh  corrupcao_indice  competitividade_indice  \
# 60  Brasil  1997  0.6464                27                   54.14
# 61  Brasil  1998  0.6526                30                   39.98
# 62  Brasil  1999  0.6588                36                   52.84
# 63  Brasil  2000  0.6650                40                   52.23
# 64  Brasil  2001  0.6704                41                   43.79
# 65  Brasil  2002  0.6758                39                   43.91
# 66  Brasil  2003  0.6812                40                   44.49
# 67  Brasil  2004  0.6866                40                   48.13
# 68  Brasil  2005  0.6920                39                   49.86
# 69  Brasil  2006  0.6950                39                   46.42
# 70  Brasil  2007  0.7000                37                   44.71
# 71  Brasil  2008  0.7050                33                   48.58
# 72  Brasil  2009  0.7080                35                   56.87
# ...

# %% [markdown]
# # Adicionar ou ajustar colunas

# %%
# ajustar
dados['idh'] = dados['idh'] * 100

# %%
dados.head(1)
# Out:
#             pais   ano    idh  corrupcao_indice  competitividade_indice  \
# 0  África do Sul  1997  63.28                56                   44.54
#
#    globalizacao_indice          pib  populacao
# 0             52.60298  148814151.0  43353.632

# %%
# nova coluna
dados['logpib']= np.log(dados['pib'])

# %%
# outra forma de adicionar uma coluna
dados['logpopulacao2'] = dados['populacao'].apply(lambda x: np.log(x))

# %%
dados.columns
# Out:
# Index(['pais', 'ano', 'idh', 'corrupcao_indice', 'competitividade_indice',
#        'globalizacao_indice', 'pib', 'populacao', 'logpib', 'logpopulacao',
#        'logpopulacao2'],
#       dtype='object')

# %%
dados = dados.drop(columns = ['logpopulacao2'])

# %%
dados.columns
# Out:
# Index(['pais', 'ano', 'idh', 'corrupcao_indice', 'competitividade_indice',
#        'globalizacao_indice', 'pib', 'populacao', 'logpib', 'logpopulacao'],
#       dtype='object')

# %% [markdown]
# # Agregações

# %%
dados.columns
# Out:
# Index(['pais', 'ano', 'idh', 'corrupcao_indice', 'competitividade_indice',
#        'globalizacao_indice', 'pib', 'populacao', 'logpib', 'logpopulacao'],
#       dtype='object')

# %%
# agregação geral - método 1
dados['idh'].mean() # média geral do idh
# Out:
# 79.98498245614036

# %%
# agregação geral - método 2
dados.agg(media_idh = pd.NamedAgg('idh', 'mean'),
          soma_pop = pd.NamedAgg('populacao', 'sum'))
# Out:
#                  idh     populacao
# media_idh  79.984982           NaN
# soma_pop         NaN  5.563626e+07

# %%
# agregação por grupo - método 1
dados.groupby('pais')['idh'].mean().reset_index()
# Out:
#               pais        idh
# 0         Alemanha  88.288000
# 1        Austrália  91.450667
# 2           Brasil  68.465333
# 3          Bélgica  87.610667
# 4           Canadá  89.048000
# 5            China  62.524000
# 6        Cingapura  82.158667
# 7           Coréia  85.690667
# 8          Espanha  85.242667
# 9   Estados Unidos  90.094667
# 10          França  86.177333
# 11         Holanda  89.132000
# 12          Itália  84.800000
# 13           Japão  88.136000
# 14          México  73.608000
# 15     Reino Unido  84.644000
# 16          Rússia  71.852000
# 17   África do Sul  61.224000
# 18           Índia  49.568000

# %%
# agregação por grupo - método 2
onu = dados.groupby('pais') \
.agg(media_idh = pd.NamedAgg('idh', 'mean')),
minimo_ano = pd.NamedAgg('ano', 'min'),
maximo_ano = pd.NamedAgg('ano', 'max')
onu
# Out:
# (                media_idh
#  pais
#  Alemanha        88.288000
#  Austrália       91.450667
#  Brasil          68.465333
#  Bélgica         87.610667
#  Canadá          89.048000
#  China           62.524000
#  Cingapura       82.158667
#  Coréia          85.690667
#  Espanha         85.242667
#  Estados Unidos  90.094667
#  França          86.177333
#  Holanda         89.132000
#  Itália          84.800000
#  Japão           88.136000
#  México          73.608000
#  Reino Unido     84.644000
#  Rússia          71.852000
#  África do Sul   61.224000
#  Índia           49.568000,)
